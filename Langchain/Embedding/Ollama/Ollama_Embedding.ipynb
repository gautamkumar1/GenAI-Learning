# %%
from langchain_community.embeddings import  OllamaEmbeddings

# %%
# Load the embeddings
# By default it is uses llma2 model
embeddings = OllamaEmbeddings(
    model="gemma2:2b"
)
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma2:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
text = [
    "Alpha is the frist letter of the Greek alphabet",
    "Beta is the second letter of the Greek alphabet",
]
r1 = embeddings.embed_documents(text)
r1
print(r1[0])
# Out:
# [-0.1042814627289772, -0.31500929594039917, -1.470634937286377, -0.07597434520721436, 0.0006581308552995324, 0.7270273566246033, 1.1047186851501465, -0.17758440971374512, -0.15295585989952087, 0.6610720157623291, -2.326526641845703, -1.1858848333358765, -1.005847454071045, -0.600001871585846, 0.09843087196350098, -0.24231688678264618, -3.1614367961883545, -0.989578127861023, -5.4522600173950195, -1.145468831062317, 1.6398977041244507, 1.711497187614441, -2.2806966304779053, -0.7656895518302917, 3.8286218643188477, -0.7053465247154236, 0.8433932065963745, 1.3239235877990723, -0.4796716272830963, 1.1910679340362549, -1.4681085348129272, 1.0260108709335327, -1.3604427576065063, -1.3082090616226196, 0.4904434084892273, 1.2990975379943848, -1.417564034461975, 0.9306876063346863, 1.0052248239517212, -2.6263680458068848, -0.48161330819129944, 2.433713674545288, -0.6993916630744934, 0.09084238111972809, -0.13384920358657837, -1.2069724798202515, -0.2462811917066574, -2.654628276824951, 2.078
# ...

# %%
embeddings.embed_query("what is the first letter of the Greek alphabet?")
# Out:
# [-1.8082904815673828,
#  0.13507196307182312,
#  -1.1959553956985474,
#  1.4629344940185547,
#  1.3606812953948975,
#  1.8026103973388672,
#  0.16291803121566772,
#  -0.09598271548748016,
#  1.4346225261688232,
#  -0.1037554144859314,
#  -0.376088947057724,
#  0.5016309022903442,
#  -2.6568527221679688,
#  0.30634504556655884,
#  -0.11796626448631287,
#  -0.7713995575904846,
#  -6.975775718688965,
#  -0.8714967370033264,
#  0.28342336416244507,
#  1.249234676361084,
#  0.5045523643493652,
#  0.836139976978302,
#  -2.015566825866699,
#  0.015610693022608757,
#  0.8156527280807495,
#  0.7818889617919922,
#  0.31428882479667664,
#  -0.7273128628730774,
#  -1.9283335208892822,
#  0.20468808710575104,
#  -0.4850452244281769,
#  0.7923374772071838,
#  -1.7906595468521118,
#  -0.6884175539016724,
#  -0.05868155509233475,
#  1.0395680665969849,
#  0.07984372973442078,
#  0.18337413668632507,
#  1.437262773513794,
#  -2.33777117729187,
#  0.6166349053382874,
#  2.554891586303711,
# ...
